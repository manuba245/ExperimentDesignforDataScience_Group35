# %%
import requests
import json
import numpy as np

# %%
url = "http://suggestqueries.google.com/complete/search"

# %%
payload={}
headers = {}

# %%
parameter_list = []

# %%
par_1 ={
    "client": "firefox",
    "q": "getting_organized_at_work",
    "hl": "en"
}
#parameter_list = parameter_list.array([par_1])
parameter_list.append(par_1)

# %%
par_2 ={
    "client": "chrome",
    "q": "getting_organized_at_work",
    "hl": "en"
}
parameter_list.append(par_2)

# %%
par_3 ={
    "client": "firefox",
    "q": "choose_bathroom",
    "hl": "en"
}
parameter_list.append(par_3)

# %%
par_4 ={
    "client": "firefox",
    "q": "low_wedding_budget",
    "hl": "en"
}
parameter_list.append(par_4)

# %%
par_5 ={
    "client": "firefox",
    "q": "lower_heart_rate",
    "hl": "en"
}
parameter_list.append(par_5)

# %%
par_6 ={
    "client": "firefox",
    "q": "website_design_hosting",
    "hl": "en"
}
parameter_list.append(par_6)

# %%
par_7 ={
    "client": "firefox",
    "q": "elliptical_trainer",
    "hl": "en"
}
parameter_list.append(par_7)

# %%
par_8 ={
    "client": "firefox",
    "q": "disneyland_paris",
    "hl": "en"
}
parameter_list.append(par_8)

# %%
par_9 ={
    "client": "firefox",
    "q": "solar_power_home",
    "hl": "en"
}
parameter_list.append(par_9)

# %%
par_10 ={
    "client": "firefox",
    "q": "build_a_fence",
    "hl": "en"
}
parameter_list.append(par_10)

# %%
par_11 ={
    "client": "firefox",
    "q": "get_rid_of_moths",
    "hl": "en"
}
parameter_list.append(par_11)

# %%
par_12 ={
    "client": "firefox",
    "q": "improve_cholesterol_levels",
    "hl": "en"
}
parameter_list.append(par_12)

# %%
par_13 ={
    "client": "firefox",
    "q": "living_in_india",
    "hl": "en"
}
parameter_list.append(par_13)

# %%
par_14 ={
    "client": "firefox",
    "q": "lose_weight_diet",
    "hl": "en"
}
parameter_list.append(par_14)

# %%
par_15 ={
    "client": "firefox",
    "q": "earn_money_online_us",
    "hl": "en"
}
parameter_list.append(par_15)

# %%
par_16 ={
    "client": "firefox",
    "q": "prepare_for_job_interview",
    "hl": "en"
}
parameter_list.append(par_16)

# %%
par_17 ={
    "client": "firefox",
    "q": "atypical_squamous_cells",
    "hl": "en"
}
parameter_list.append(par_17)

# %%
par_18 ={
    "client": "firefox",
    "q": "spider_bites",
    "hl": "en"
}
parameter_list.append(par_18)

# %%
par_19 ={
    "client": "firefox",
    "q": "sangre_de_cristo_mountains_hike",
    "hl": "en"
}
parameter_list.append(par_19)

# %%
par_20 ={
    "client": "firefox",
    "q": "altitude_sickness_peru",
    "hl": "en"
}
parameter_list.append(par_20)

# %%
par_21 ={
    "client": "firefox",
    "q": "septic_system_options",
    "hl": "en"
}
parameter_list.append(par_21)

# %%
par_22 ={
    "client": "firefox",
    "q": "barbados_holidays",
    "hl": "en"
}
parameter_list.append(par_22)

# %%
par_60 ={
    "client": "firefox",
    "q": "first_aid_heart_attack",
    "hl": "en"
}
parameter_list.append(par_60)

# %%
par_23 ={
    "client": "firefox",
    "q": "long_term_care_insurance_canada",
    "hl": "en"
}
parameter_list.append(par_23)

# %%
par_24 ={
    "client": "firefox",
    "q": "how_to_cook_pork_tenderloin",
    "hl": "en"
}
parameter_list.append(par_24)

# %%
par_25 ={
    "client": "firefox",
    "q": "buy_condo_in_florida",
    "hl": "en"
}
parameter_list.append(par_25)

# %%
par_26 ={
    "client": "firefox",
    "q": "organize_wedding",
    "hl": "en"
}
parameter_list.append(par_26)

# %%
par_27 ={
    "client": "firefox",
    "q": "prepare_home_for_winter",
    "hl": "en"
}
parameter_list.append(par_27)

# %%
par_28 ={
    "client": "firefox",
    "q": "support_human_rights",
    "hl": "en"
}
parameter_list.append(par_28)

# %%
par_29 ={
    "client": "firefox",
    "q": "school_bullying",
    "hl": "en"
}
parameter_list.append(par_29)

# %%
par_30 ={
    "client": "firefox",
    "q": "adopt_a_child_in_california",
    "hl": "en"
}
parameter_list.append(par_30)

# %%
par_31 ={
    "client": "firefox",
    "q": "acid_stain_concrete",
    "hl": "en"
}
parameter_list.append(par_31)

# %%
par_32 ={
    "client": "firefox",
    "q": "pole_vault",
    "hl": "en"
}
parameter_list.append(par_32)

# %%
par_33 ={
    "client": "firefox",
    "q": "bird_spotting",
    "hl": "en"
}
parameter_list.append(par_33)

# %%
par_34 ={
    "client": "firefox",
    "q": "white_water_rafting",
    "hl": "en"
}
parameter_list.append(par_34)

# %%
par_35 ={
    "client": "firefox",
    "q": "invest_in_mutual_funds",
    "hl": "en"
}
parameter_list.append(par_35)

# %%
par_36 ={
    "client": "firefox",
    "q": "braid_extensions",
    "hl": "en"
}
parameter_list.append(par_36)

# %%
par_37 ={
    "client": "firefox",
    "q": "start_a_vineyard",
    "hl": "en"
}
parameter_list.append(par_37)

# %%
par_38 ={
    "client": "firefox",
    "q": "buy_girl_scout_cookies",
    "hl": "en"
}
parameter_list.append(par_38)

# %%
par_39 ={
    "client": "firefox",
    "q": "open_a_bank_account",
    "hl": "en"
}
parameter_list.append(par_39)

# %%
par_40 ={
    "client": "firefox",
    "q": "french_manicure",
    "hl": "en"
}
parameter_list.append(par_40)

# %%
par_41 ={
    "client": "firefox",
    "q": "extend_laptop_warranty",
    "hl": "en"
}
parameter_list.append(par_41)

# %%
par_42 ={
    "client": "firefox",
    "q": "fake_tan_at_home",
    "hl": "en"
}
parameter_list.append(par_42)

# %%
par_43 ={
    "client": "firefox",
    "q": "sell_used_laptop_online",
    "hl": "en"
}
parameter_list.append(par_43)

# %%
par_44 ={
    "client": "firefox",
    "q": "invest_in_stock_market",
    "hl": "en"
}
parameter_list.append(par_44)

# %%
par_45 ={
    "client": "firefox",
    "q": "windows_10_troubleshoot",
    "hl": "en"
}
parameter_list.append(par_45)

# %%
par_46 ={
    "client": "firefox",
    "q": "apply_for_aadhar_card",
    "hl": "en"
}
parameter_list.append(par_46)

# %%
par_47 ={
    "client": "firefox",
    "q": "test_for_diabetes",
    "hl": "en"
}
parameter_list.append(par_47)

# %%
par_48 ={
    "client": "firefox",
    "q": "buttons_for_websites",
    "hl": "en"
}
parameter_list.append(par_48)

# %%
par_49 ={
    "client": "firefox",
    "q": "social_media_for_learning",
    "hl": "en"
}
parameter_list.append(par_49)

# %%
par_50 ={
    "client": "firefox",
    "q": "home_remedies_sore_throat",
    "hl": "en"
}
parameter_list.append(par_50)

# %%
par_51 ={
    "client": "firefox",
    "q": "golf_instruction",
    "hl": "en"
}
parameter_list.append(par_51)

# %%
par_52 ={
    "client": "firefox",
    "q": "hair_dye",
    "hl": "en"
}
parameter_list.append(par_52)

# %%
par_53 ={
    "client": "firefox",
    "q": "build_hip_roof",
    "hl": "en"
}
parameter_list.append(par_53)

# %%
par_54 ={
    "client": "firefox",
    "q": "build_home_theater_system",
    "hl": "en"
}
parameter_list.append(par_54)

# %%
par_55 ={
    "client": "firefox",
    "q": "finding_planets_in_the_night_sky",
    "hl": "en"
}
parameter_list.append(par_55)

# %%
par_56 ={
    "client": "firefox",
    "q": "make_a_teddy_bear",
    "hl": "en"
}
parameter_list.append(par_56)

# %%
par_57 ={
    "client": "firefox",
    "q": "browse_the_internet_anonymously",
    "hl": "en"
}
parameter_list.append(par_57)

# %%
par_58 ={
    "client": "firefox",
    "q": "morel_mushrooms_hunting",
    "hl": "en"
}
parameter_list.append(par_58)

# %%
par_59 ={
    "client": "firefox",
    "q": "watch_tv_on_the_internet",
    "hl": "en"
}
parameter_list.append(par_59)

# %%
par_61 ={
    "client": "firefox",
    "q": "regrow_hair",
    "hl": "en"
}
parameter_list.append(par_61)

# %%
par_62 ={
    "client": "firefox",
    "q": "get_a_divorce_in_texas",
    "hl": "en"
}
parameter_list.append(par_62)

# %%
par_63 ={
    "client": "firefox",
    "q": "build_raised_gardens",
    "hl": "en"
}
parameter_list.append(par_63)

# %%
par_64 ={
    "client": "firefox",
    "q": "dangers_of_asbestos_in_the_home",
    "hl": "en"
}
parameter_list.append(par_64)

# %%
par_65 ={
    "client": "firefox",
    "q": "sit_and_reach_test_at_home",
    "hl": "en"
}
parameter_list.append(par_65)

# %%
par_66 ={
    "client": "firefox",
    "q": "flowering_plants_for_cold_climates",
    "hl": "en"
}
parameter_list.append(par_66)

# %%
par_67 ={
    "client": "firefox",
    "q": "live_with_fibromyalgia",
    "hl": "en"
}
parameter_list.append(par_67)

# %%
par_68 ={
    "client": "firefox",
    "q": "how_to_tell_if_roof_needs_to_be_repaired",
    "hl": "en"
}
parameter_list.append(par_68)

# %%
par_69 ={
    "client": "firefox",
    "q": "make_a_small_apartment_look_larger",
    "hl": "en"
}
parameter_list.append(par_69)

# %%
par_70 ={
    "client": "firefox",
    "q": "paint_home_interiror_walls",
    "hl": "en"
}
parameter_list.append(par_70)

# %%
par_71 ={
    "client": "firefox",
    "q": "saftey_tips_for_hurricane",
    "hl": "en"
}
parameter_list.append(par_71)

# %%
par_72 ={
    "client": "firefox",
    "q": "add_value_to_home_for_sale",
    "hl": "en"
}
parameter_list.append(par_72)

# %%
par_73 ={
    "client": "firefox",
    "q": "how_to_become_an_art_investor",
    "hl": "en"
}
parameter_list.append(par_73)

# %%
par_74 ={
    "client": "firefox",
    "q": "support_human_rights",
    "hl": "en"
}
parameter_list.append(par_74)

# %%
par_75 ={
    "client": "firefox",
    "q": "single_mother_in_the_uk",
    "hl": "en"
}
parameter_list.append(par_75)

# %%
par_76 ={
    "client": "firefox",
    "q": "deal_with_a_depressed_family_member",
    "hl": "en"
}
parameter_list.append(par_76)

# %%
par_77 ={
    "client": "firefox",
    "q": "raise_an_autistic_child",
    "hl": "en"
}
parameter_list.append(par_77)

# %%
par_78 ={
    "client": "firefox",
    "q": "raise_venture_capital_ca",
    "hl": "en"
}
parameter_list.append(par_78)

# %%
par_79 ={
    "client": "firefox",
    "q": "set_up_an_amateur_radio",
    "hl": "en"
}
parameter_list.append(par_79)

# %%
par_80 ={
    "client": "firefox",
    "q": "taking_care_of_swimming_pool",
    "hl": "en"
}
parameter_list.append(par_80)

# %%
par_81 ={
    "client": "firefox",
    "q": "become_an_allergist",
    "hl": "en"
}
parameter_list.append(par_81)

# %%
par_82 ={
    "client": "firefox",
    "q": "care_for_a_toy_poodle",
    "hl": "en"
}
parameter_list.append(par_82)

# %%
par_83 ={
    "client": "firefox",
    "q": "cure_indigestion	",
    "hl": "en"
}
parameter_list.append(par_83)

# %%
par_84 ={
    "client": "firefox",
    "q": "setup_living_room",
    "hl": "en"
}
parameter_list.append(par_84)

# %%
par_85 ={
    "client": "firefox",
    "q": "customize_your_own_tshirt",
    "hl": "en"
}
parameter_list.append(par_85)

# %%
par_86 ={
    "client": "firefox",
    "q": "drivers_license_united_kingdom",
    "hl": "en"
}
parameter_list.append(par_86)

# %%
par_87 ={
    "client": "firefox",
    "q": "setup_a_garage_sale",
    "hl": "en"
}
parameter_list.append(par_87)

# %%
par_88 ={
    "client": "firefox",
    "q": "apply_for_government_job_in_india",
    "hl": "en"
}
parameter_list.append(par_88)

# %%
par_89 ={
    "client": "firefox",
    "q": "grow_flowering_plants_from_seed",
    "hl": "en"
}
parameter_list.append(par_89)

# %%
par_90 ={
    "client": "firefox",
    "q": "recycling_lead_acid_batteries_in_new_jersey",
    "hl": "en"
}
parameter_list.append(par_90)

# %%
par_91 ={
    "client": "firefox",
    "q": "prevent_a_heart_attact",
    "hl": "en"
}
parameter_list.append(par_91)

# %%
par_92 ={
    "client": "firefox",
    "q": "learn_to_dance_hip-hop",
    "hl": "en"
}
parameter_list.append(par_92)

# %%
par_93 ={
    "client": "firefox",
    "q": "transfer_money_online_united_states",
    "hl": "en"
}
parameter_list.append(par_93)

# %%
par_94 ={
    "client": "firefox",
    "q": "deliver_a_baby_at_home",
    "hl": "en"
}
parameter_list.append(par_94)

# %%
result_list = []
for i in parameter_list:
    r=requests.get(url, params=i)
    suggestions = json.loads(r.text)
    print(i["q"]+" :")
    result_list.append(i["q"]+" :")
    for word in suggestions[1]:
        print(word.encode("ascii", "ignore"))
        result_list.append(word.encode("ascii", "ignore"))
# Out:
# getting_organized_at_work :
# b'getting organized at work'
# b'getting organized at work pdf'
# b'getting organized at work and home'
# b'getting and staying organized at work'
# b'getting better organized at work'
# b'how to be an organized person at work'
# b'how to be extremely organized at work'
# b'how to keep organized at work'
# getting_organized_at_work :
# b'getting organized at work'
# b'getting organized at work pdf'
# b'getting organized at work and home'
# b'getting and staying organized at work'
# b'getting better organized at work'
# b'how to be an organized person at work'
# b'how to be extremely organized at work'
# b'how to keep organized at work'
# choose_bathroom :
# b'choose bathroom tiles'
# b'choose bathroom fan'
# b'choose bathroom colors'
# b'choose bathroom vanity'
# b'choose bathroom exhaust fan'
# b'choose bathroom taps'
# b'choose bathroom lighting'
# b'choose bathroom faucets'
# b'choose bathroom countertops'
# b'how to choose bathroom'
# ...

# %%
result_list
# Out:
# ['getting_organized_at_work :',
#  b'getting organized at work',
#  b'getting organized at work pdf',
#  b'getting organized at work and home',
#  b'getting and staying organized at work',
#  b'getting better organized at work',
#  b'how to be an organized person at work',
#  b'how to be extremely organized at work',
#  b'how to keep organized at work',
#  'getting_organized_at_work :',
#  b'getting organized at work',
#  b'getting organized at work pdf',
#  b'getting organized at work and home',
#  b'getting and staying organized at work',
#  b'getting better organized at work',
#  b'how to be an organized person at work',
#  b'how to be extremely organized at work',
#  b'how to keep organized at work',
#  'choose_bathroom :',
#  b'choose bathroom tiles',
#  b'choose bathroom fan',
#  b'choose bathroom colors',
#  b'choose bathroom vanity',
#  b'choose bathroom exhaust fan',
#  b'choose bathroom taps',
#  b'choose bathroom lighting',
#  b'choose bathroom faucets',
# ...

# %%
with open("GoogleQS.txt", "a") as output:
    for suggestion in result_list:
        output.write(str('%s\n' % suggestion))
